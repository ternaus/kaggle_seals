# %%
# %matplotlib inline
from pylab import *
import cv2

# %%
from scipy.ndimage.morphology import binary_opening, generate_binary_structure

# %%
import os
import cv2

# %%
image_dotted = cv2.imread('../data/TrainDotted/530.jpg')

# %%
image = cv2.imread('../data/Train/530.jpg')

# %%
imshow(image)

# %%
struct_el = generate_binary_structure(2, 2)

# %%
fill_color = [0, 0, 0]

# %%
zero_mask = (img == 0).astype(float)

# %%
mask = np.all(image_dotted == 0, axis=2)

# %%
mask_dil = binary_opening(mask, structure=struct_el, iterations=6)

# %%
image_black_out = image.copy()

# %%
image_black_out[mask_dil] = fill_color
# Out:
# /home/vladimir/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 5616 but corresponding boolean dimension is 3744
#   if __name__ == '__main__':
# ---------------------------------------------------------------------
# IndexError                          Traceback (most recent call last)
# <ipython-input-49-a2a3758ec642> in <module>()
# ----> 1 image_black_out[mask_dil] = fill_color
#
# IndexError: index 5072 is out of bounds for axis 1 with size 3744

# %%
imshow(image_black_out)
